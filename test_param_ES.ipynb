# %%
import numpy as np 
from test_functions import *
from evaluation_strategy_basic import *
from matplotlib import pyplot as plt

# %%
    D=10
    bound=[-100,100]
    bounds=[bound for i in range(D)]
    model=ES_1_1(iterations=5000,bound=bounds,evaluator=sphere)
    print('best fitness=',model.result['best'][-1],'\n best_solution=',model.result['best_solution'][-1])
    print('mutation strength',model.mutation_strength)
    ax1=plt.subplot(111)
    ax1.plot(np.arange(len(model.result['best'])),model.result['best'],'b')
    ax1.plot(np.arange(len(model.result['best'])),model.result['mean'],'r')
    plt.show()
# Out:
# best fitness= 6.292624310892477e-59
#  best_solution= [ 5.15369957e-30  8.11601173e-33  2.22943729e-30  1.57505634e-30
#   9.44186880e-31  5.11581348e-30 -2.49165526e-31 -1.11370057e-30
#   5.54060656e-31 -4.91866699e-31]
# mutation strength 1.5706555487582352e-30

# %%
    D=10
    bound=[-10,10]
    bounds=[bound for i in range(D)]
    model=ES_1_1(iterations=5000,bound=bounds,evaluator=sum_squares)
    print('best fitness=',model.result['best'][-1],'\n best_solution=',model.result['best_solution'][-1])
    print('mutation strength',model.mutation_strength)
    ax1=plt.subplot(111)
    ax1.plot(np.arange(len(model.result['best'])),model.result['best'],'b')
    ax1.plot(np.arange(len(model.result['best'])),model.result['mean'],'r')
    plt.show()
# Out:
# best fitness= 2.9781498635204947e-33
#  best_solution= [-5.03236709e-17  7.92288444e-18 -3.70220512e-18  1.49719286e-18
#   2.65939905e-18 -7.19623459e-19  2.28422318e-18 -3.98186269e-18
#  -2.34801139e-18 -1.36364760e-18]
# mutation strength 1.1316221325515226e-18

# %%
    D=10
    bound=[-1000,1000]
    bounds=[bound for i in range(D)]
    model=ES_1_1(iterations=5000,bound=bounds,evaluator=step)
    print('best fitness=',model.result['best'][-1],'\n best_solution=',model.result['best_solution'][-1])
    print('mutation strength',model.mutation_strength)
    ax1=plt.subplot(111)
    ax1.plot(np.arange(len(model.result['best'])),model.result['best'],'b')
    ax1.plot(np.arange(len(model.result['best'])),model.result['mean'],'r')
    plt.show()
# Out:
# best fitness= 0
#  best_solution= [ 0.02004601  0.12655274  0.05199362 -1.26896986 -0.53438781 -0.62220045
#   0.31848514 -0.74327404 -0.74545161 -1.18971807]
# mutation strength 0.5000000000000001

# %%
    D=10
    bound=[-1.28,1.28]
    bounds=[bound for i in range(D)]
    model=ES_1_1(iterations=5000,bound=bounds,evaluator=quartic)
    print('best fitness=',model.result['best'][-1],'\n best_solution=',model.result['best_solution'][-1])
    print('mutation strength',model.mutation_strength)
    ax1=plt.subplot(111)
    ax1.plot(np.arange(len(model.result['best'])),model.result['best'],'b')
    ax1.plot(np.arange(len(model.result['best'])),model.result['mean'],'r')
    plt.show()
# Out:
# best fitness= 0.8690288273710127
#  best_solution= [ 5.21810932e-05 -4.30301238e-05 -3.23952637e-05  4.81568257e-05
#  -4.41909484e-05 -1.50036151e-05 -3.19931701e-05 -4.79905117e-05
#  -4.71316668e-05  2.65101067e-05]
# mutation strength 1.7879786322745424e-05

# %%
    D=2
    bound=[-100,100]
    bounds=[bound for i in range(D)]
    model=ES_1_1(iterations=5000,bound=bounds,evaluator=easom)
    print('best fitness=',model.result['best'][-1],'\n best_solution=',model.result['best_solution'][-1])
    print('mutation strength',model.mutation_strength)
    ax1=plt.subplot(111)
    ax1.plot(np.arange(len(model.result['best'])),model.result['best'],'b')
    ax1.plot(np.arange(len(model.result['best'])),model.result['mean'],'r')
    plt.show()
# Out:
# best fitness= -1.0
#  best_solution= [3.14159265 3.14159265]
# mutation strength 3.160097098876727e-08

# %%
D=2
bound=[-10,10]
bounds=[bound for i in range(D)]
model=ES_1_1(iterations=5000,bound=bounds,evaluator=matyas)
print('best fitness=',model.result['best'][-1],'\n best_solution=',model.result['best_solution'][-1])
print('sigma',model.mutation_strength)
ax1=plt.subplot(111)
ax1.plot(np.arange(len(model.result['best'])),model.result['best'],'b')
ax1.plot(np.arange(len(model.result['best'])),model.result['mean'],'r')
plt.show()
# Out:
# best fitness= 5.093114289673396e-185
#  best_solution= [-2.57672268e-92 -3.36680247e-92]
# sigma 5.247654696206771e-92

# %%
    D=2
    bound=[-100,100]
    bounds=[bound for i in range(D)]
    model=ES_mu_lambda(population_size=50,offspring_size=500,iterations=5000,bound=bounds,evaluator=sphere)
    print('best fitness=',model.result['best'][-1],'\n best_solution=',model.result['best_solution'][-1])
    print('sigma',model.result['sigma'])
    ax1=plt.subplot(111)
    ax1.plot(np.arange(len(model.result['best'])),model.result['best'],'b')
    ax1.plot(np.arange(len(model.result['best'])),model.result['mean'],'r')
    plt.show()
# Out:
# best fitness= 0.0
#  best_solution= [-7.63954801e-163  7.78721617e-163]
# sigma [2.60506996e-174 3.45060984e-174]

# %%
D=10
bound=[-10,10]
bounds=[bound for i in range(D)]
model=ES_mu_lambda(population_size=50,offspring_size=500,iterations=5000,bound=bounds,evaluator=sum_squares)
print('best fitness=',model.result['best'][-1],'\n best_solution=',model.result['best_solution'][-1])
print('sigma',model.result['sigma'])
ax1=plt.subplot(111)
ax1.plot(np.arange(len(model.result['best'])),model.result['best'],'b')
ax1.plot(np.arange(len(model.result['best'])),model.result['mean'],'r')
plt.show()
# Out:
# best fitness= 0.001183511639801855
#  best_solution= [-3.43591104e-02 -2.74241791e-04 -3.35854179e-05  2.33231709e-04
#   5.69633954e-04  1.09187966e-05 -1.41944446e-04 -2.79339736e-04
#   1.96431757e-05  1.41385421e-04]
# sigma [1.15729876e-05 1.50352706e-04 2.55962045e-04 1.49553291e-04
#  1.47606122e-04 1.89985693e-04 1.37314702e-04 1.53189813e-04
#  1.82871749e-04 1.40576501e-04]

# %%
D=10
bound=[-100,100]
bounds=[bound for i in range(D)]
model=ES_mu_lambda(population_size=100,offspring_size=500,iterations=5000,bound=bounds,evaluator=step)
print('best fitness=',model.result['best'][-1],'\n best_solution=',model.result['best_solution'][-1])
print('sigma',model.result['sigma'])
ax1=plt.subplot(111)
ax1.plot(np.arange(len(model.result['best'])),model.result['best'],'b')
ax1.plot(np.arange(len(model.result['best'])),model.result['mean'],'r')
plt.show()
# Out:
# best fitness= 0
#  best_solution= [-1.26282005 -0.34760548 -0.36981298 -1.26304574  0.2683969  -0.11106833
#  -0.73522914 -0.25459568 -0.11138527  0.07856606]
# sigma [1.00986571e-21 3.26301954e-22 5.35953693e-22 1.68184380e-22
#  3.90533660e-22 5.63450482e-22 8.46645673e-22 3.19241445e-22
#  3.09272878e-22 8.39136469e-22]

# %%
D=10
bound=[-1.28,1.28]
bounds=[bound for i in range(D)]
model=ES_mu_lambda(population_size=50,offspring_size=500,iterations=5000,bound=bounds,evaluator=quartic)
print('best fitness=',model.result['best'][-1],'\n best_solution=',model.result['best_solution'][-1])
print('sigma',model.result['sigma'])
ax1=plt.subplot(111)
ax1.plot(np.arange(len(model.result['best'])),model.result['best'],'b')
ax1.plot(np.arange(len(model.result['best'])),model.result['mean'],'r')
plt.show()
# Out:
# best fitness= 0.13461676570057227
#  best_solution= [-8.10794155e-06 -1.91574502e-04  3.68692730e-05  8.40633461e-06
#  -8.93596602e-06 -8.19825246e-06  8.32836456e-06 -7.95288611e-06
#   1.96579812e-05 -1.65257380e-05]
# sigma [4.13727474e-06 9.33004508e-08 1.03435917e-05 4.49619799e-06
#  7.76884614e-06 8.46856445e-06 1.10501060e-05 5.21237132e-06
#  5.94991379e-06 6.47082414e-06]

# %%
D=2
bound=[-100,100]
bounds=[bound for i in range(D)]
model=ES_mu_lambda(population_size=50,offspring_size=500,iterations=5000,bound=bounds,evaluator=easom)
print('best fitness=',model.result['best'][-1],'\n best_solution=',model.result['best_solution'][-1])
print('sigma',model.result['sigma'])
ax1=plt.subplot(111)
ax1.plot(np.arange(len(model.result['best'])),model.result['best'],'b')
ax1.plot(np.arange(len(model.result['best'])),model.result['mean'],'r')
plt.show()
# Out:
# best fitness= -1.0
#  best_solution= [3.14159266 3.14159266]
# sigma [5.46337140e-12 5.05986392e-12]

# %%
D=2
bound=[-10,10]
bounds=[bound for i in range(D)]
model=ES_mu_lambda(population_size=50,offspring_size=500,iterations=5000,bound=bounds,evaluator=matyas)
print('best fitness=',model.result['best'][-1],'\n best_solution=',model.result['best_solution'][-1])
print('sigma',model.result['sigma'])
ax1=plt.subplot(111)
ax1.plot(np.arange(len(model.result['best'])),model.result['best'],'b')
ax1.plot(np.arange(len(model.result['best'])),model.result['mean'],'r')
plt.show()
# Out:
# best fitness= 0.0
#  best_solution= [-4.27940661e-163 -2.47345235e-162]
# sigma [3.17203205e-175 3.79649348e-176]
